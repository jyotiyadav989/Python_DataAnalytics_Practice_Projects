# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
data = pd.read_csv(r"C:\Users\jyoti\Desktop\udemyda\Rename\DataSets\HousingData.csv")
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# 13546  11/1/2019         england         248515  E92000001      67814.0
# 13547  12/1/2019         england         250410  E92000001          NaN
# 13548   1/1/2020         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %%
data.columns
# Out:
# Index(['date', 'area', 'average_price', 'code', 'houses_sold', 'no_of_crimes'], dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=13549, step=1)

# %%
data.shape
# Out:
# (13549, 6)

# %%
data.describe()
# Out:
#        average_price    houses_sold  no_of_crimes
# count   1.354900e+04   13455.000000   7439.000000
# mean    2.635197e+05    3893.994129   2158.352063
# std     1.876175e+05   12114.402476    902.087742
# min     4.072200e+04       2.000000      0.000000
# 25%     1.323800e+05     247.000000   1623.000000
# 50%     2.229190e+05     371.000000   2132.000000
# 75%     3.368430e+05    3146.000000   2582.000000
# max     1.463378e+06  132163.000000   7461.000000

# %%
data.dtypes
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %%
data['Ndate'] = pd.to_datetime(data['date'])

# %%
data.dtypes
# Out:
# date                     object
# area                     object
# average_price             int64
# code                     object
# houses_sold             float64
# no_of_crimes            float64
# Ndate            datetime64[ns]
# dtype: object

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# Ndate               0
# dtype: int64

# %%
data.nunique()
# Out:
# date               301
# area                45
# average_price    13343
# code                45
# houses_sold       3946
# no_of_crimes      2669
# Ndate              301
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # TASKS:

# %% [markdown]
# 1. ADD A NEW COL YEAR IN A DF THAT CONTAINS YEARS ONLY.

# %%
data.head(2)
# Out:
#        date            area  average_price       code  houses_sold  \
# 0  1/1/1995  city of london          91449  E09000001         17.0
# 1  2/1/1995  city of london          82203  E09000001          7.0
#
#    no_of_crimes      Ndate
# 0           NaN 1995-01-01
# 1           NaN 1995-02-01

# %%
data['Ndate'].dt.year
# Out:
# 0        1995
# 1        1995
# 2        1995
# 3        1995
# 4        1995
#          ...
# 13544    2019
# 13545    2019
# 13546    2019
# 13547    2019
# 13548    2020
# Name: Ndate, Length: 13549, dtype: int32

# %%
data['Year'] = data['Ndate'].dt.year

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# 13546  11/1/2019         england         248515  E92000001      67814.0
# 13547  12/1/2019         england         250410  E92000001          NaN
# 13548   1/1/2020         england         247355  E92000001          NaN
#
#        no_of_crimes      Ndate  Year
# 0               NaN 1995-01-01  1995
# ...

# %% [markdown]
# 2. ADD A NEW COL MONTH AS SECOND POSITION IN THE DF , WHICH CONTAINS MONTHS ONLY.

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# 13546  11/1/2019         england         248515  E92000001      67814.0
# 13547  12/1/2019         england         250410  E92000001          NaN
# 13548   1/1/2020         england         247355  E92000001          NaN
#
#        no_of_crimes      Ndate  Year  Month
# 0               NaN 1995-01-01  1995      1
# ...

# %% [markdown]
# - ADD IT AFTER AREA COL.

# %%
data.insert(2, 'month' , data.Ndate.dt.month)

# %%
data
# Out:
#             date            area  month  average_price       code  \
# 0       1/1/1995  city of london      1          91449  E09000001
# 1       2/1/1995  city of london      2          82203  E09000001
# 2       3/1/1995  city of london      3          79121  E09000001
# 3       4/1/1995  city of london      4          77101  E09000001
# 4       5/1/1995  city of london      5          84409  E09000001
# ...          ...             ...    ...            ...        ...
# 13544   9/1/2019         england      9         249942  E92000001
# 13545  10/1/2019         england     10         249376  E92000001
# 13546  11/1/2019         england     11         248515  E92000001
# 13547  12/1/2019         england     12         250410  E92000001
# 13548   1/1/2020         england      1         247355  E92000001
#
#        houses_sold  no_of_crimes      Ndate  Year  Month
# 0             17.0           NaN 1995-01-01  1995      1
# 1              7.0           NaN 1995-02-01  1995      2
# ...

# %% [markdown]
# 3. REMOVE THE COL YEAR AND MONTH FROM THE DF.

# %%
data.head(2)
# Out:
#        date            area  month  average_price       code  houses_sold  \
# 0  1/1/1995  city of london      1          91449  E09000001         17.0
# 1  2/1/1995  city of london      2          82203  E09000001          7.0
#
#    no_of_crimes      Ndate  Year  Month
# 0           NaN 1995-01-01  1995      1
# 1           NaN 1995-02-01  1995      2

# %%
data.drop(['month', 'Year', 'Month'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 data.drop(['month', 'Year', 'Month'], axis=1, inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
# ...

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# 13546  11/1/2019         england         248515  E92000001      67814.0
# 13547  12/1/2019         england         250410  E92000001          NaN
# 13548   1/1/2020         england         247355  E92000001          NaN
#
#        no_of_crimes      Ndate
# 0               NaN 1995-01-01
# 1               NaN 1995-02-01
# ...

# %% [markdown]
# 4. SHOW ALL THE RECORDS WHERE 'NO. OF CRIMES' IS 0 AND HOW MANY SUCH RECORDS ARE THERE?

# %%
data.head(2)
# Out:
#        date            area  average_price       code  houses_sold  \
# 0  1/1/1995  city of london          91449  E09000001         17.0
# 1  2/1/1995  city of london          82203  E09000001          7.0
#
#    no_of_crimes      Ndate
# 0           NaN 1995-01-01
# 1           NaN 1995-02-01

# %%
data[data.no_of_crimes==0]
# Out:
#           date            area  average_price       code  houses_sold  \
# 72    1/1/2001  city of london         284262  E09000001         24.0
# 73    2/1/2001  city of london         198137  E09000001         37.0
# 74    3/1/2001  city of london         189033  E09000001         44.0
# 75    4/1/2001  city of london         205494  E09000001         38.0
# 76    5/1/2001  city of london         223459  E09000001         30.0
# ..         ...             ...            ...        ...          ...
# 178  11/1/2009  city of london         397909  E09000001         11.0
# 179  12/1/2009  city of london         411955  E09000001         16.0
# 180   1/1/2010  city of london         464436  E09000001         20.0
# 181   2/1/2010  city of london         490525  E09000001          9.0
# 182   3/1/2010  city of london         498241  E09000001         15.0
#
#      no_of_crimes      Ndate
# 72            0.0 2001-01-01
# 73            0.0 2001-02-01
# 74            0.0 2001-03-01
# ...

# %%
len(data[data.no_of_crimes==0])
# Out:
# 104

# %% [markdown]
# 5. what is the max and min 'avg price' per year in england?

# %%
data.head(2)
# Out:
#        date            area  average_price       code  houses_sold  \
# 0  1/1/1995  city of london          91449  E09000001         17.0
# 1  2/1/1995  city of london          82203  E09000001          7.0
#
#    no_of_crimes      Ndate
# 0           NaN 1995-01-01
# 1           NaN 1995-02-01

# %%
data['area']
# Out:
# 0        city of london
# 1        city of london
# 2        city of london
# 3        city of london
# 4        city of london
#               ...
# 13544           england
# 13545           england
# 13546           england
# 13547           england
# 13548           england
# Name: area, Length: 13549, dtype: object

# %%
data['areaE'] = data['area'] == 'england'

# %%
data.head(2)
# Out:
#        date            area  average_price       code  houses_sold  \
# 0  1/1/1995  city of london          91449  E09000001         17.0
# 1  2/1/1995  city of london          82203  E09000001          7.0
#
#    no_of_crimes      Ndate  Year  areaE
# 0           NaN 1995-01-01  1995  False
# 1           NaN 1995-02-01  1995  False

# %%
data['areaE'].nunique()
# Out:
# 2

# %%
data['Year'] = data['Ndate'].dt.year

# %%
data.groupby('Year').average_price.min()
# Out:
# Year
# 1995     41688
# 1996     40722
# 1997     42353
# 1998     43510
# 1999     43969
# 2000     47604
# 2001     49045
# 2002     54746
# 2003     67520
# 2004     88520
# 2005    110454
# 2006    121124
# 2007    131175
# 2008    120275
# 2009    117079
# 2010    119688
# 2011    115328
# 2012    113011
# 2013    112008
# 2014    114531
# 2015    117156
# 2016    121085
# 2017    121858
# 2018    124038
# 2019    124567
# 2020    126592
# Name: average_price, dtype: int64

# %%
data[data.area == 'england'].Year.min()
# Out:
# 1995

# %%
data[data.area == 'england'].Year.max()
# Out:
# 2020

# %%
data.groupby('Year').average_price.max()  #ans
# Out:
# Year
# 1995     200722
# 1996     223197
# 1997     265112
# 1998     277600
# 1999     354241
# 2000     397353
# 2001     451028
# 2002     497538
# 2003     488704
# 2004     559286
# 2005     555847
# 2006     644541
# 2007     830950
# 2008     832753
# 2009     782459
# 2010     884674
# 2011     959520
# 2012    1077366
# 2013    1217729
# 2014    1365050
# 2015    1353679
# 2016    1357231
# 2017    1412255
# 2018    1463378
# 2019    1294113
# 2020    1178166
# Name: average_price, dtype: int64

# %%
data.groupby('Year').average_price.min()   #ans
# Out:
# Year
# 1995     41688
# 1996     40722
# 1997     42353
# 1998     43510
# 1999     43969
# 2000     47604
# 2001     49045
# 2002     54746
# 2003     67520
# 2004     88520
# 2005    110454
# 2006    121124
# 2007    131175
# 2008    120275
# 2009    117079
# 2010    119688
# 2011    115328
# 2012    113011
# 2013    112008
# 2014    114531
# 2015    117156
# 2016    121085
# 2017    121858
# 2018    124038
# 2019    124567
# 2020    126592
# Name: average_price, dtype: int64

# %% [markdown]
# 6. WHAT IS THE MAX AND MIN NO. OF CRIMES RECORDED PER AREA?

# %%
data.head(2)
# Out:
#        date            area  average_price       code  houses_sold  \
# 0  1/1/1995  city of london          91449  E09000001         17.0
# 1  2/1/1995  city of london          82203  E09000001          7.0
#
#    no_of_crimes      Ndate  Year  areaE
# 0           NaN 1995-01-01  1995  False
# 1           NaN 1995-02-01  1995  False

# %%
data.groupby('area').no_of_crimes.max().sort_values(ascending = False)
# Out:
# area
# westminster               7461.0
# lambeth                   4701.0
# camden                    4558.0
# southwark                 3821.0
# newham                    3668.0
# hackney                   3466.0
# ealing                    3401.0
# islington                 3384.0
# tower hamlets             3316.0
# croydon                   3263.0
# haringey                  3199.0
# wandsworth                3051.0
# waltham forest            2941.0
# brent                     2937.0
# barnet                    2893.0
# greenwich                 2853.0
# hillingdon                2819.0
# hounslow                  2817.0
# lewisham                  2813.0
# enfield                   2798.0
# kensington and chelsea    2778.0
# hammersmith and fulham    2645.0
# bromley                   2637.0
# redbridge                 2560.0
# barking and dagenham      2049.0
# havering                  1956.0
# bexley                    1914.0
# harrow                    1763.0
# ...

# %%
data.groupby('area').no_of_crimes.min().sort_values(ascending = True)
# Out:
# area
# city of london               0.0
# kingston upon thames       692.0
# richmond upon thames       700.0
# sutton                     787.0
# merton                     819.0
# bexley                     860.0
# harrow                     937.0
# havering                  1130.0
# barking and dagenham      1217.0
# hammersmith and fulham    1323.0
# kensington and chelsea    1347.0
# bromley                   1441.0
# hillingdon                1445.0
# redbridge                 1487.0
# greenwich                 1513.0
# hounslow                  1529.0
# haringey                  1536.0
# waltham forest            1575.0
# wandsworth                1582.0
# enfield                   1635.0
# tower hamlets             1646.0
# lewisham                  1675.0
# barnet                    1703.0
# brent                     1850.0
# hackney                   1870.0
# ealing                    1871.0
# islington                 1871.0
# croydon                   2031.0
# ...

# %%
7. SHOW THE TOTAL NUMBER OF RECORDS OF EACH AREA WHERE AVG PRICE IS LESS THAN 100000

# %%
data.head(2)
# Out:
#        date            area  average_price       code  houses_sold  \
# 0  1/1/1995  city of london          91449  E09000001         17.0
# 1  2/1/1995  city of london          82203  E09000001          7.0
#
#    no_of_crimes      Ndate  Year  areaE
# 0           NaN 1995-01-01  1995  False
# 1           NaN 1995-02-01  1995  False

# %%
data[data.average_price < 100000].area.value_counts()
# Out:
# area
# north east              112
# north west              111
# yorks and the humber    110
# east midlands            96
# west midlands            94
# england                  87
# barking and dagenham     85
# south west               78
# east of england          76
# newham                   72
# bexley                   64
# waltham forest           64
# lewisham                 62
# havering                 60
# south east               59
# greenwich                59
# croydon                  57
# enfield                  54
# sutton                   54
# hackney                  53
# redbridge                52
# southwark                48
# tower hamlets            47
# outer london             46
# hillingdon               44
# lambeth                  41
# hounslow                 41
# brent                    40
# london                   39
# merton                   35
# haringey                 33
# bromley                  33
# inner london             31
# ...
